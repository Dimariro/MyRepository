# %% [markdown]
# ipynb = Interactive Python notebook
# # Inclusión del Titulo y despues Ctrl Enter
# ## Subtitulo
# ### Sub Sub Titulo

# %% [markdown]
# [link Anaconda](https://www.google.com/search?q=anaconda+python&rlz=1C1GCEB_enUS803CO803&oq=&aqs=chrome.4.69i59i450l8.212599106j0j7&sourceid=chrome&ie=UTF-8)
#
# [Cómo aprender Markdown](https://www.markdownguide.org/basic-syntax)
#
# Para agregar una **imagen de internet**, la buscas en internet y le das click derecho y le dices Open image in a new window, copias el link y lo pegas
#
# ![Schnoodle](data:image/jpeg;base64,...)
#
# ![Anaconda_Task_1.PNG](data:image/png;base64,...)

# %% [markdown]
# *Colocar un asterisco te permite que se vea en cursiva*, ojo sin espacios en blanco
#
# **Colocar doble asterisco te deja en bold** ojo sin espacios en blanco
#
# ***Colocar en cursiva y bold es con tres asteriscos***
#
# >Sangria es con signo de mayor que

# %% [markdown]
# # Ahora con LaTex
#
# Esto quiere decir que vamos a usar LaTex para escribir las formulas que utilizamos, hace mucho que no escribo en LaTex **Recordar es vivir**
#
# $$Y=x^2$$
# $$\frac{dx}{dt}=KC$$

# %%
print("Hola Mundo")
# Out:
# Hola Mundo
